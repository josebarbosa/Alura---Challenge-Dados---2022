# %%
import pandas as pd;

# %%
dados = pd.read_csv("ids.csv")
dados.shape
# Out:
# (34501, 18)

# %%
dados.head()
# Out:
#        pessoa_id  emprestimo_id          cb_id    pessoa_id.1  pessoa_idade  \
# 0  F9a6bBd9-Xe2o  8HuvzhAq-k7Xi  L42AQtMx-SEGR  F9a6bBd9-Xe2o          27.0
# 1  RSQpYv0W-D6Oo  PDpdl2hQ-Sszr  oZ2iPvfD-HdIo  RSQpYv0W-D6Oo          24.0
# 2  bRYeof0L-cqHI  0T2YFLWb-IZze  0Y1a64ag-4RLW  bRYeof0L-cqHI          30.0
# 3  d0YRlkdZ-nuLT  xzTEiD3e-BbFZ  Z5LA433k-5vqf  d0YRlkdZ-nuLT          28.0
# 4  njGBnugm-85Dv  QKDlpIm7-sqMC  ObEkaKZr-9MDa  njGBnugm-85Dv          30.0
#
#    pessoa_renda pessoa_casa_propria  pessoa_duracao_emprestimo  \
# 0       68000.0             Aluguel                        4.0
# 1       12600.0             Aluguel                        2.0
# 2      100000.0             Aluguel                       13.0
# 3       83000.0            Hipoteca                        6.0
# 4      110400.0             Aluguel                        1.0
#
#   emprestimo_id.1            emprestimo_tipo emprestimo_risco  \
# 0   8HuvzhAq-k7Xi  Financiamento Imobiliário                A
# ...

# %%
dados = dados.dropna()

# %%
dados.head()
# Out:
#        pessoa_id  emprestimo_id          cb_id    pessoa_id.1  pessoa_idade  \
# 0  F9a6bBd9-Xe2o  8HuvzhAq-k7Xi  L42AQtMx-SEGR  F9a6bBd9-Xe2o          27.0
# 1  RSQpYv0W-D6Oo  PDpdl2hQ-Sszr  oZ2iPvfD-HdIo  RSQpYv0W-D6Oo          24.0
# 2  bRYeof0L-cqHI  0T2YFLWb-IZze  0Y1a64ag-4RLW  bRYeof0L-cqHI          30.0
# 4  njGBnugm-85Dv  QKDlpIm7-sqMC  ObEkaKZr-9MDa  njGBnugm-85Dv          30.0
# 6  GN6ytQnE-DzMK  WbeWEny4-1t34  mMtKwh3x-cEpY  GN6ytQnE-DzMK          24.0
#
#    pessoa_renda pessoa_casa_propria  pessoa_duracao_emprestimo  \
# 0       68000.0             Aluguel                        4.0
# 1       12600.0             Aluguel                        2.0
# 2      100000.0             Aluguel                       13.0
# 4      110400.0             Aluguel                        1.0
# 6      117996.0            Hipoteca                        6.0
#
#   emprestimo_id.1            emprestimo_tipo emprestimo_risco  \
# 0   8HuvzhAq-k7Xi  Financiamento Imobiliário                A
# ...

# %%
dados.shape
# Out:
# (28638, 18)
